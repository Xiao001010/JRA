# %%
import os
import numpy as np

from cellpose import models, io

# %%
file_list = os.listdir('data/Fluo-C2DL-Huh7/02')

if not os.path.exists('data/Fluo_mask_data'):
    os.mkdir('data/Fluo_mask_data')

model = models.Cellpose(gpu=True, model_type='cyto')

for file in file_list:
    if file.endswith('.tif'):
        print(file)
        
        img = io.imread('data/Fluo-C2DL-Huh7/02/' + file)
        print(img.shape)
        break
        masks, flows, styles, diams = model.eval(img, diameter=30, channels=[0,0])
        np.save('data/Fluo_mask_data/' + '02' + file[:-4] + '_mask.npy', masks)
# Out:
# t000.tif
# (1024, 1024)

# %%
import tifffile
import numpy as np

mean = np.array([6076.685883679818, 1350.9691095158794, 5090.145564947434, 5019.978020658786])
std = np.array([5504.395544161098, 1145.6356702621574, 663.3312283427825, 706.0040270727409])

img1 = tifffile.imread('logs/Fixed20_Res_VAE-sigma_0.001-larger_newNormalize/2023-07-20_16-03-59/reconstruction_500.tif')
img2 = tifffile.imread('logs/Fixed20_Res_VAE-sigma_0.001-larger_newNormalize/2023-07-20_16-03-59/original_500.tif')
img3 = tifffile.imread('data/single_cell_data/0_69.tif')

print(img1.shape)

for i in range(4):
    img1[i] = img1[i] * std[i] + mean[i]
    img2[i] = img2[i] * std[i] + mean[i]
# # print(img3.shape)
# Out:
# (4, 32, 32)

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
plt.subplot(2, 2, 1)
plt.imshow(img2[0], cmap='gray')
plt.colorbar()
plt.subplot(2, 2, 2)
plt.imshow(img2[1], cmap='gray')
plt.colorbar()
plt.subplot(2, 2, 3)
plt.imshow(img2[2], cmap='gray')
plt.colorbar()
plt.subplot(2, 2, 4)
plt.imshow(img2[3], cmap='gray')
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
plt.subplot(2, 2, 1)
plt.imshow(img1[0], cmap='gray')
plt.colorbar()
plt.subplot(2, 2, 2)
plt.imshow(img1[1], cmap='gray')
plt.colorbar()
plt.subplot(2, 2, 3)
plt.imshow(img1[2], cmap='gray')
plt.colorbar()
plt.subplot(2, 2, 4)
plt.imshow(img1[3], cmap='gray')
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
plt.subplot(2, 2, 1)
plt.imshow(img3[0], cmap='gray', vmax=15000)
plt.colorbar()
plt.subplot(2, 2, 2)
plt.imshow(img3[1], cmap='gray', vmax=15000)
plt.colorbar()
plt.subplot(2, 2, 3)
plt.imshow(img3[2], cmap='gray', vmax=8000)
plt.colorbar()
plt.subplot(2, 2, 4)
plt.imshow(img3[3], cmap='gray', vmax=8000)
plt.colorbar()
plt.show()

# %%
import tifffile
import numpy as np

mean = np.array([6076.685883679818, 1350.9691095158794, 5090.145564947434, 5019.978020658786])
std = np.array([5504.395544161098, 1145.6356702621574, 663.3312283427825, 706.0040270727409])

img1 = tifffile.imread('logs/2chnto4chn_ResVAE/2023-07-19_16-12-55/reconstruction_480.tif')
img2 = tifffile.imread('logs/2chnto4chn_ResVAE/2023-07-19_16-12-55/original_480.tif')
# img3 = tifffile.imread('data/single_cell_data/0_69.tif')

print(img1.shape)

# for i in range(4):
#     img1[i] = img1[i] * std[i] + mean[i]
#     img2[i] = img2[i] * std[i] + mean[i]
# # print(img3.shape)
# Out:
# (4, 32, 32)

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
plt.subplot(2, 2, 1)
plt.imshow(img2[0], cmap='gray')
plt.colorbar()
plt.subplot(2, 2, 2)
plt.imshow(img2[1], cmap='gray')
plt.colorbar()
plt.subplot(2, 2, 3)
plt.imshow(img2[2], cmap='gray')
plt.colorbar()
plt.subplot(2, 2, 4)
plt.imshow(img2[3], cmap='gray')
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
plt.subplot(2, 2, 1)
plt.imshow(img1[0], cmap='gray')
plt.colorbar()
plt.subplot(2, 2, 2)
plt.imshow(img1[1], cmap='gray')
plt.colorbar()
plt.subplot(2, 2, 3)
plt.imshow(img1[2], cmap='gray')
plt.colorbar()
plt.subplot(2, 2, 4)
plt.imshow(img1[3], cmap='gray')
plt.colorbar()
plt.show()

# %% [markdown]
# Calculate mean and std of dataset

# %%
import os
import tifffile
import numpy as np

data_path = 'data/single_cell_data/'

file_list = os.listdir(data_path)

# mean_tmpt, std_tmpt = [], []
# mean, std = [], []

# for i in range(4):
#     for file in file_list:
#         if file.endswith('.tif'):
#             img = tifffile.imread(data_path + file)
#             mean_tmpt.append(np.mean(img[i]))
#             std_tmpt.append(np.std(img[i]))
#     mean.append(np.mean(mean_tmpt))
#     std.append(np.mean(std_tmpt))
#     mean_tmpt, std_tmpt = [], []

print(mean)
print(std)
# Out:
# [6076.685883679818, 1350.9691095158794, 5090.145564947434, 5019.978020658786]
# [5504.395544161098, 1145.6356702621574, 663.3312283427825, 706.0040270727409]

# %%
import numpy as np

mean = np.array([6076.685883679818, 1350.9691095158794, 5090.145564947434, 5019.978020658786])
std = np.array([5504.395544161098, 1145.6356702621574, 663.3312283427825, 706.0040270727409])

# %%
import os
import tifffile

data_path = 'data/single_cell_data/'

file_list = os.listdir(data_path)

idx = 25

img = tifffile.imread(data_path + file_list[idx])
print(img.shape)

img = img.astype(np.float32)

for i in range(4):
    img[i] = (img[i] - mean[i]) / std[i]
# img = (img - mean) / std



import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
plt.imshow(img[0], cmap='gray')
plt.colorbar()
plt.subplot(2, 2, 2)
plt.imshow(img[1], cmap='gray')
plt.colorbar()
plt.subplot(2, 2, 3)
plt.imshow(img[2], cmap='gray')
plt.colorbar()
plt.subplot(2, 2, 4)
plt.imshow(img[3], cmap='gray')
plt.colorbar()
plt.show()
# Out:
# (4, 20, 18)
